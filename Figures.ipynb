# %%
# %pylab notebook
mpl.rcParams['figure.figsize'] = (12,10)
mpl.rcParams['lines.linewidth'] = 0.8
from spike.Interactive import INTER 
INTER.hidecode()
# Out:
# Populating the interactive namespace from numpy and matplotlib
#
# ...
#           SPIKE
# ...
#     Version     : 0.99.21
#     Date        : 23-02-2021
#     Revision Id : 490
# ...
# *** zoom3D not loaded ***
# plugins loaded:
# Fitter,  Linear_prediction,  Peaks,  bcorr,  fastclean,  gaussenh,  rem_ridge,  sane,  sg,  test,  urQRd,
#
# spike.plugins.report() for a short description of each plugins
# spike.plugins.report('module_name') for complete documentation on one plugin
# plugins loaded:
# Bruker_NMR_FT,  Bucketing,  Integrate,  PALMA,  apmin,
# <style>
# hr         {height: 2px; border: 0;border-top: 1px solid #ccc;margin: 1em 0;padding: 0; }
# .container {width:100% !important; }
# </style>
# <script>
# code_show=false;
# function code_toggle()
#     { if (code_show)
#         { $('div.input').hide(); $('#but').val("show python code");
#         } else { $('div.input').show(); $('#but').val("hide python code");
#     }
#     code_show = !code_show }
# $(document).ready(code_toggle);
# ...

# %%
from SNRvsRank import figure

# %%
figure(steprank=4)
# Out:
# rank  20
# rank  40
# rank  60
# rank  80
# rank  100
# rank  120
# rank  140
# rank  160
# rank  180
# rank  200
# rank  220
# rank  240
# rank  260
# rank  280
# rank  300
# rank  320
# rank  340
# rank  360
# rank  380
# rank  400
# rank  420
# rank  440
# rank  460
# <img src="data:image/png;base64,..." width="787">

# %%
from figure_sup2 import main

# %%
main(meth='rQRd', zoom=(18000,45000))
plt.savefig('urQRdz.pdf')
# Out:
# <img src="data:image/png;base64,..." width="1200">
# Initial Noisy Data SNR: 4.39 dB - noise type : additive
# === Running rQRd algo ===
# lendata: 100000
#  orda: 15000
#  rank: 40
# Final Data SNR: 13.64 dB - noise type : additive
#
# Initial Noisy Data SNR: -7.84 dB - noise type : scintillation
# === Running rQRd algo ===
# lendata: 100000
#  orda: 15000
#  rank: 40
# Final Data SNR: 6.70 dB - noise type : scintillation
# elaps: 6.748511791229248
# /home/mad/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
main(meth='SANE', zoom=(18000,45000))
plt.savefig('SANEz.pdf')
# Out:
# <img src="data:image/png;base64,..." width="1200">
# Initial Noisy Data SNR: 4.42 dB - noise type : additive
# === Running SANE algo ===
# lendata: 100000
#  orda: 15000
#  rank: 24
# Final Data SNR: 29.28 dB - noise type : additive
#
# Initial Noisy Data SNR: -7.78 dB - noise type : scintillation
# === Running SANE algo ===
# lendata: 100000
#  orda: 15000
#  rank: 24
# Final Data SNR: 6.15 dB - noise type : scintillation
# elaps: 3.5053954124450684
# /home/mad/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
